# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Automobile.csv")

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.tail()
# Out:
#                 name   mpg  cylinders  displacement  horsepower  weight  \
# 393  ford mustang gl  27.0          4         140.0        86.0    2790
# 394        vw pickup  44.0          4          97.0        52.0    2130
# 395    dodge rampage  32.0          4         135.0        84.0    2295
# 396      ford ranger  28.0          4         120.0        79.0    2625
# 397       chevy s-10  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin
# 393          15.6          82     usa
# 394          24.6          82  europe
# 395          11.6          82     usa
# 396          18.6          82     usa
# 397          19.4          82     usa

# %%
df.ndim
# Out:
# 2

# %%
df.nunique()
# Out:
# name            305
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# dtype: int64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.isnull()
# Out:
#       name    mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False  False      False         False       False   False         False
# 1    False  False      False         False       False   False         False
# 2    False  False      False         False       False   False         False
# 3    False  False      False         False       False   False         False
# 4    False  False      False         False       False   False         False
# ..     ...    ...        ...           ...         ...     ...           ...
# 393  False  False      False         False       False   False         False
# 394  False  False      False         False       False   False         False
# 395  False  False      False         False       False   False         False
# 396  False  False      False         False       False   False         False
# 397  False  False      False         False       False   False         False
#
#      model_year  origin
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# name             object
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'mpg'}>,
#         <Axes: title={'center': 'cylinders'}>,
#         <Axes: title={'center': 'displacement'}>],
#        [<Axes: title={'center': 'horsepower'}>,
#         <Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'acceleration'}>],
#        [<Axes: title={'center': 'model_year'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
x=df['name']
y=df['horsepower']

# %%
plt.scatter(x,y)
plt.xlablel('name')
plt.ylabel('horsepower')
plt.show

# %%
m=df['horsepower'].median()

# %%
m
# Out:
# 93.5

# %%
low_horsepower=df.query('horsepower<{}'.format(m))

# %%
high_horsepower=df.query('horsepower>{}'.format(m))

# %%
high_horsepower
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 363              buick century  22.4          6         231.0       110.0
# 364      oldsmobile cutlass ls  26.6          8         350.0       105.0
# 386      buick century limited  25.0          6         181.0       110.0
# 389             ford granada l  22.0          6         232.0       112.0
# 390           toyota celica gt  32.0          4         144.0        96.0
#
#      weight  acceleration  model_year origin
# ...

# %%
low_horsepower
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 17                  ford maverick  21.0          6         200.0        85.0
# 18                   datsun pl510  27.0          4          97.0        88.0
# 19   volkswagen 1131 deluxe sedan  26.0          4          97.0        46.0
# 20                    peugeot 504  25.0          4         110.0        87.0
# 21                    audi 100 ls  24.0          4         107.0        90.0
# ..                            ...   ...        ...           ...         ...
# 393               ford mustang gl  27.0          4         140.0        86.0
# 394                     vw pickup  44.0          4          97.0        52.0
# 395                 dodge rampage  32.0          4         135.0        84.0
# 396                   ford ranger  28.0          4         120.0        79.0
# 397                    chevy s-10  31.0          4         119.0        82.0
#
# ...

# %%
mean_horsepower_of_low_horsepower=low_horsepower['horsepower'].mean()

# %%
mean_horsepower_of_high_horsepower=high_horsepower['horsepower'].mean()

# %%
location=[1,2]
heights=[mean_horsepower_of_low_horsepower,mean_horsepower_of_high_horsepower]
labels=["low","high"]
plt.bar(location,heights,tick_label=labels)
plt.title("average horsepower")
plt.xlabel('horsepower')
plt.ylabel('average horsepower')
plt.show()

# %%
sns.barplot(x='cylinders',y='model_year',data=df[50:80])
# Out:
# <Axes: xlabel='cylinders', ylabel='model_year'>

# %%
sns.countplot(y=df['model_year'],palette='Set1')
# Out:
# <Axes: xlabel='count', ylabel='model_year'>

# %%
df.nlargest(10,["horsepower"])
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 116            pontiac grand prix  16.0          8         400.0       230.0
# 8                pontiac catalina  14.0          8         455.0       225.0
# 13        buick estate wagon (sw)  14.0          8         455.0       225.0
# 95       buick electra 225 custom  12.0          8         455.0       225.0
# 6                chevrolet impala  14.0          8         454.0       220.0
# 7               plymouth fury iii  14.0          8         440.0       215.0
# 25                      ford f250  10.0          8         360.0       215.0
# 94   chrysler new yorker brougham  13.0          8         440.0       215.0
# 27                     dodge d200  11.0          8         318.0       210.0
# 67                mercury marquis  11.0          8         429.0       208.0
#
#      weight  acceleration  model_year origin
# 116    4278           9.5          73    usa
# ...

# %%
df.nlargest(10,["displacement"])
# Out:
#                             name   mpg  cylinders  displacement  horsepower  \
# 8               pontiac catalina  14.0          8         455.0       225.0
# 13       buick estate wagon (sw)  14.0          8         455.0       225.0
# 95      buick electra 225 custom  12.0          8         455.0       225.0
# 6               chevrolet impala  14.0          8         454.0       220.0
# 7              plymouth fury iii  14.0          8         440.0       215.0
# 94  chrysler new yorker brougham  13.0          8         440.0       215.0
# 5               ford galaxie 500  15.0          8         429.0       198.0
# 67               mercury marquis  11.0          8         429.0       208.0
# 90      mercury marquis brougham  12.0          8         429.0       198.0
# 12         chevrolet monte carlo  15.0          8         400.0       150.0
#
#     weight  acceleration  model_year origin
# 8     4425          10.0          70    usa
# ...
